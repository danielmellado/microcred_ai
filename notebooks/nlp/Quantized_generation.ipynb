# %%
# Install the latest compatible versions of the required libraries
# Note: This takes a while, It's also better to use %pip as it
# installs into the environment that the notebook kernel is running in
# and allows to not having to restart the kernel most times.
# %pip install --upgrade --verbose transformers datasets torch bitsandbytes accelerate

print("Libraries installed/updated")
print("‼️ IMPORTANT: Please restart the runtime now (Runtime -> Restart session) before proceeding.")
# Out:
# Using pip 25.2 from /home/torch/venv/lib/python3.10/site-packages/pip (python 3.10)
# ...
# Note: you may need to restart the kernel to use updated packages.
# Libraries installed/updated
# ‼️ IMPORTANT: Please restart the runtime now (Runtime -> Restart session) before proceeding.

# %%
# Function definitions
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
import time
import os
import gc

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

def measure_vram(load_model_func):
    if DEVICE == "cpu":
        # No VRAM to measure on CPU
        model = load_model_func()
        return model, 0

    gc.collect()
    torch.cuda.empty_cache()
    torch.cuda.reset_peak_memory_stats(DEVICE)
    vram_before = torch.cuda.max_memory_allocated(DEVICE)
    model = load_model_func()
    torch.cuda.synchronize(DEVICE)
    vram_after = torch.cuda.max_memory_allocated(DEVICE)
    vram_used = (vram_after - vram_before) / 1e6  # Convert to MB
    return model, vram_used

def load_quantized_model():
    quantization_config = BitsAndBytesConfig(load_in_4bit=True)
    m = AutoModelForCausalLM.from_pretrained(
        MODEL_NAME,
        quantization_config=quantization_config,
        torch_dtype=torch.bfloat16,
        trust_remote_code=True,
        device_map="auto"
    )
    return m


def get_vram_usage():
    if DEVICE == "cpu":
        return 0
    return torch.cuda.memory_allocated() / 1e6

def clear_vram():
    if DEVICE == "cpu":
        return
    gc.collect()
    torch.cuda.empty_cache()


# --- Data Storage ---
model_data = []

print(f"Running on device: {DEVICE}")
if DEVICE == "cpu":
    print("WARNING: This notebook is optimized for GPU. CPU execution will be slow and VRAM will not be measured.")
# Out:
# Running on device: cuda

# %%
# Load models
MODEL_NAME = "Qwen/Qwen2-1.5B-Instruct"

# Load BF16 (Baseline) Model
print(f"Loading: BF16 (Baseline) for {MODEL_NAME}")

def load_bf16_model():
    m = AutoModelForCausalLM.from_pretrained(
        MODEL_NAME,
        torch_dtype=torch.bfloat16,
        trust_remote_code=True,
        device_map=DEVICE
    )
    return m

model_bf16, vram_bf16 = measure_vram(load_bf16_model)
model_data.append({
    "name": "BF16 (Baseline)",
    "model": model_bf16,
    "vram_mb": vram_bf16
})
print(f"Model loaded. Peak VRAM used by this model: {vram_bf16:.2f} MB")

# Load INT8 (8-bit) Model
print(f"Loading: INT8 (8-bit) for {MODEL_NAME}")

def load_int8_model():
    config = BitsAndBytesConfig(load_in_8bit=True)
    m = AutoModelForCausalLM.from_pretrained(
        MODEL_NAME,
        quantization_config=config,
        torch_dtype=torch.bfloat16,
        trust_remote_code=True,
        device_map="auto"
    )
    return m

model_int8, vram_int8 = measure_vram(load_int8_model)
model_data.append({
    "name": "INT8 (8-bit)",
    "model": model_int8,
    "vram_mb": vram_int8
})
print(f"Model loaded. Peak VRAM used by this model: {vram_int8:.2f} MB")

# Load NF4 (4-bit) Model
print(f"Loading: NF4 (4-bit) for {MODEL_NAME}")

def load_nf4_model():
    config = BitsAndBytesConfig(load_in_4bit=True)
    m = AutoModelForCausalLM.from_pretrained(
        MODEL_NAME,
        quantization_config=config,
        torch_dtype=torch.bfloat16,
        trust_remote_code=True,
        device_map="auto"
    )
    return m

model_nf4, vram_nf4 = measure_vram(load_nf4_model)
model_data.append({
    "name": "NF4 (4-bit)",
    "model": model_nf4,
    "vram_mb": vram_nf4
})
print(f"Model loaded. Peak VRAM used by this model: {vram_nf4:.2f} MB\n")
print(f"All models loaded.")

tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME, trust_remote_code=True)
print("Tokenizer loaded.")
# Out:
# Loading: BF16 (Baseline) for Qwen/Qwen2-1.5B-Instruct
# Model loaded. Peak VRAM used by this model: 3087.95 MB
# Loading: INT8 (8-bit) for Qwen/Qwen2-1.5B-Instruct
# Model loaded. Peak VRAM used by this model: 1830.32 MB
# Loading: NF4 (4-bit) for Qwen/Qwen2-1.5B-Instruct
# Model loaded. Peak VRAM used by this model: 1270.48 MB
#
# All models loaded.
# Tokenizer loaded.

# %%
# --- Generate text ---
import random

print("Generating Text...\n")
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

SEED = int.from_bytes(os.urandom(4), byteorder="big")
PROMPT = "In a galaxy far, far away," # Try different prompts

for data in model_data:
    print(f"Generating with: {MODEL_NAME} {data['name']}...")
    torch.manual_seed(SEED)  # Same seed for each model for deterministic comparison

    inputs = tokenizer(PROMPT, return_tensors="pt").to(DEVICE)

    start_time = time.time()
    outputs = data["model"].generate(
        **inputs,
        max_new_tokens=200,
        do_sample=True,
        temperature=0.7, # Experiment with different temperatures
        top_p=0.9,
        top_k=50,
        pad_token_id=tokenizer.eos_token_id # Suppress warning
    )
    end_time = time.time()

    data["inference_time_s"] = end_time - start_time
    data["generated_text"] = tokenizer.decode(outputs[0], skip_special_tokens=True)
    print(f"Completed in {data['inference_time_s']:.2f} seconds.\n")

print("All text generations complete.")
# Out:
# Generating Text...
#
# Generating with: Qwen/Qwen2-1.5B-Instruct BF16 (Baseline)...
# Completed in 2.92 seconds.
#
# Generating with: Qwen/Qwen2-1.5B-Instruct INT8 (8-bit)...
# /home/torch/venv/lib/python3.10/site-packages/bitsandbytes/autograd/_functions.py:181: UserWarning: MatMul8bitLt: inputs will be cast from torch.bfloat16 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
# Completed in 14.47 seconds.
#
# Generating with: Qwen/Qwen2-1.5B-Instruct NF4 (4-bit)...
# Completed in 4.57 seconds.
#
# All text generations complete.

# %%
# Print the output and the comparison

import textwrap # For the output to be readable on a screen

print("="*80)
print(" " * 25 + "COMPARISON: GENERATED TEXT")
print("="*80 + "\n")

for data in model_data:
    print(f"### MODEL: {MODEL_NAME}: {data['name']} ###")
    print("-" * 50)
    wrapped_text = textwrap.fill(data["generated_text"], width=80)
    print(wrapped_text)

    print("\n" + "="*80 + "\n")


print("\n" + "="*80)
print(" " * 24 + "COMPARISON: RESOURCE USAGE")
print("="*80 + "\n")

# --- Header ---
print(f"{'Model Precision':<20} | {'VRAM Usage (MB)':<20} | {'Inference Time (s)':<22} |")
print(f"{'':-<20} | {'':-<20} | {'':-<22} |")

# --- Table Rows ---
for data in model_data:
    name = data['name']
    vram = f"{data['vram_mb']:.2f}"
    inf_time = f"{data['inference_time_s']:.2f}"
    print(f"{name:<20} | {vram:<20} | {inf_time:<22} |")

print("\n" + "="*80 + "\n")
# Out:
# ...
#                          COMPARISON: GENERATED TEXT
# ...
#
# ### MODEL: Qwen/Qwen2-1.5B-Instruct: BF16 (Baseline) ###
# --------------------------------------------------
# In a galaxy far, far away, there are planets where people can grow plants to
# eat. On one planet, the food supply is based on 30% of all edible matter found
# on it. A farmer has a field that produces 240 kg of edible matter per day and
# wants to maximize the amount of plant-based food they can produce in 10 days.
# Assuming the same conditions apply for each of the other planets in the system,
# how many kilograms of plant-based food could the farmer produce?  Given: - The
# farm's field produces 240 kg of edible matter daily. - The planet's food
# production rate is 30% of the total edible matter available. - The farmer aims
# to harvest 10 days' worth of plant-based food. - There are no specific details
# about the size or composition of any individual planets within the given
# ...

# %% [markdown]
# # Quantization Results Analysis
#
# ## Understanding Quantization Methods
#
# BF16 is the baseline precision format that uses 16 bits to store numbers,
# providing the best accuracy and numerical stability. Modern GPUs are
# well-optimized for this format, making it fast and reliable. INT8 reduces model
# weights to 8-bit integers, which significantly decreases memory usage but
# requires constant conversion between different number formats during inference.
# This conversion overhead is what's causing the slowdown in your the. NF4 is a
# specialized 4-bit quantization format designed specifically for transformer
# models, which gives greatmemory savings without the conversion bottlenecks that
# affect INT8 as stated below.
#
# ## Performance Comparison
#
# | Model Type | VRAM Usage | Memory Savings | Inference Time | Speed vs Baseline |
# |------------|------------|----------------|----------------|-------------------|
# | BF16 (Baseline) | 3087.43 MB | - | 2.92s | Reference |
# | INT8 (8-bit) | 1843.10 MB | -40% | 14.47s | **5x slower** due to casting |
# | NF4 (4-bit) | 1521.11 MB | -51% | 4.57s | 1.6x slower |
#
#
#
# ## Generated text
#
# Taking a look at the generated text seems that we can also differentiate this a
# little bit:
#
# * **BF16 baseline**:
#    Reading it, it looks the most coherent and rich. Even if I
#    was thinking about Star Wars this still seemscoherent and creates a kinda
#    interesting and surprising agricultural modeling.
# *  **INT8 quantized model**:
#    Somehow seems a bit simpler buit still creates a mathematical scenario, even
#    if a bit incoherent.
# * **NF4 model**: It's a bit degraded as it creates a
#    probablilty problem kinda related to the original baseline model reasoning.
#
# The varying prompt interpretations across models incicate that the model
# quantization affects no just the compute efficiency but the model's creativity.
# I'd still like to check playing witht the temperature of the quantized models.
#
# ## Summary
#
# After checking the table and the outcome, it may seem that **NF4 quantization**
# improves things a lot here for this specific model. We'd need to recall that
# inference time will be probably affected by this
#
# ```
# MatMul8bitLt: inputs will be cast from torch.bfloat16 to float16 during
# quantization
# ```
# The model loads in `bfloat16` format, but INT8 quantization requires `float16`
# as an intermediate step. This means:
# - **Input**: bfloat16 → float16 → INT8
# - **Computation**: INT8 operations
# - **Output**: INT8 → float16 → bfloat16
#
# Each conversion adds computational overhead, especially when done repeatedly
# during matrix multiplications.  The results show that **NF4 quantization is the
# best choice here**. While it uses 51% less memory than BF16, it only increases
# inference time by 60%, making it an excellent balance of efficiency and
# performance. The **INT8 quantization**, despite offering 40% memory savings,
# suffers from severe performance degradation with 5x slower inference times,
# due to data type conversion overhead and the mentioned hardware support.
